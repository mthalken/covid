# %%
# Dependencies
import pandas as pd

# %%
# Read CSV
county_levels = pd.read_csv('data/United_States_COVID-19_Community_Levels_by_County.csv')
cases_deaths = pd.read_csv('data/United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv')
death_counts = pd.read_csv('data/Provisional_COVID-19_Death_Counts_in_the_United_States_by_County.csv')

# %%
county_levels
# Out:
#                                              county  county_fips  \
# 0                                    American Samoa        60000
# 1                                              Guam        66000
# 2      Commonwealth of the Northern Mariana Islands        69000
# 3                      United States Virgin Islands        78000
# 4                                    American Samoa        60000
# ...                                             ...          ...
# 19339                                Gooding County        16047
# 19340                                American Samoa        60000
# 19341                                          Guam        66000
# 19342  Commonwealth of the Northern Mariana Islands        69000
# 19343                  United States Virgin Islands        78000
#
#                                               state county_population  \
# 0                                    American Samoa            47,392
# ...

# %%
cases_deaths
# Out:
#       submission_date state tot_cases conf_cases prob_cases new_case  \
# 0          08/14/2020    WA    66,066        NaN        NaN      898
# 1          08/17/2020    MD   100,715        NaN        NaN      503
# 2          03/28/2022    VT   107,785        NaN        NaN      467
# 3          03/18/2020    ME        44         44          0       12
# 4          02/06/2020    NE         0        NaN        NaN        0
# ...               ...   ...       ...        ...        ...      ...
# 48055      07/20/2021    RI   145,399        NaN        NaN       47
# 48056      09/20/2020    SC   141,073    136,366      4,707      952
# 48057      07/11/2020    RI    16,456        NaN        NaN       52
# 48058      07/04/2021    KY   463,215    347,059    116,156      117
# 48059      04/10/2020    OR     1,371        NaN        NaN       50
#
#       pnew_case tot_death conf_death prob_death new_death pnew_death  \
# ...

# %%
cases_deaths.dtypes
# Out:
# submission_date    object
# state              object
# tot_cases          object
# conf_cases         object
# prob_cases         object
# new_case           object
# pnew_case          object
# tot_death          object
# conf_death         object
# prob_death         object
# new_death          object
# pnew_death         object
# created_at         object
# consent_cases      object
# consent_deaths     object
# dtype: object

# %%
covert_dict = {
#     'submission_date' : datetime,
               'state': str,
               'tot_cases': int,
               'conf_cases': int,
               'prob_cases': int,
               'new_case': int, 
               'pnew_case': int,
               'tot_death': int,
               'conf_death': int,
               'prob_death': int,
               'new_death': int,
               'pnew_death': int,
#                'created_at': datetime,
               'consent_cases': int,
               'consent_deaths': int 
              }

# %%
cases_deaths = cases_deaths.astype(covert_dict)
cases_deaths
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22884/1828702186.py in <module>
# ----> 1 cases_deaths = cases_deaths.astype(covert_dict)
#       2 cases_deaths
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5797                 if col_name in dtype:
#    5798                     results.append(
# -> 5799                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5800                     )
#    5801                 else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
df = cases_deaths.groupby(['submission_date'])
df

# %%
death_counts
# Out:
#       Date as of  Start Date    End Date State             County name  \
# 0     03/30/2022  01/01/2020  03/26/2022    AK  Aleutians East Borough
# 1     03/30/2022  01/01/2020  03/26/2022    AK  Anchorage Municipality
# 2     03/30/2022  01/01/2020  03/26/2022    AK      Bethel Census Area
# 3     03/30/2022  01/01/2020  03/26/2022    AK          Denali Borough
# 4     03/30/2022  01/01/2020  03/26/2022    AK  Dillingham Census Area
# ...          ...         ...         ...   ...                     ...
# 3065  03/30/2022  01/01/2020  03/26/2022    WY       Sweetwater County
# 3066  03/30/2022  01/01/2020  03/26/2022    WY            Teton County
# 3067  03/30/2022  01/01/2020  03/26/2022    WY            Uinta County
# 3068  03/30/2022  01/01/2020  03/26/2022    WY         Washakie County
# 3069  03/30/2022  01/01/2020  03/26/2022    WY           Weston County
#
#       FIPS County Code Urban Rural Code  Deaths involving COVID-19  \
# ...

# %%
death_counts_by_county_3_20 = death_counts[['FIPS County Code', 'Deaths involving COVID-19', 'Deaths from All Causes']]
death_counts_by_county_3_20.rename(columns={'FIPS County Code': 'county_fips', 'Deaths involving COVID-19': 'deaths_involving_covid', 'Deaths from All Causes': 'deaths_from_all_causes'})
# Out:
#       county_fips  deaths_involving_covid  deaths_from_all_causes
# 0            2013                     NaN                    16.0
# 1            2020                   657.0                  5611.0
# 2            2050                    32.0                   258.0
# 3            2068                     NaN                    14.0
# 4            2070                     NaN                    74.0
# ...           ...                     ...                     ...
# 3065        56037                    98.0                   774.0
# 3066        56039                    18.0                   207.0
# 3067        56041                    20.0                   326.0
# 3068        56043                    27.0                   184.0
# 3069        56045                     NaN                   154.0
#
# [3070 rows x 3 columns]
